# %% [markdown]
# # Web3 Community and Education sybil analysis
#
# This notebooks looks for patterns of sybil bahevior in the Web3 Community and Education round.
#
# This round was selected because during the grant review I flagged many projects from this round as suspicious.
#
#
# We use sybil-scorer as well as new metrics to identify suspicious behavior.
#
# We will then manually review the addresses using etherscan and DeBank to confirm our suspicions.
#
# Then we try to see if any project is more affected by these flagged addresses in particular to back up our claims of suspicious project applications. This will also allow us to see if the sybil behavior is targeted towards a specific project.

# %%
import os
from pathlib import Path
import numpy as np

import pandas as pd

from sbdata.FlipsideApi import FlipsideApi

# Set path to data folder
current_dir = Path(os.getcwd())
PATH_TO_EXPORT = os.path.join(current_dir.parent.parent, 'tx_data', 'web3_community_and_education')
DATA_DIR = os.path.join(current_dir.parent.parent, 'data-regen-rangers')

# read the address from oss grant

api_key = os.environ['FLIPSIDE_API_KEY']
flipside_api = FlipsideApi(api_key, max_address=400)
PATH_TO_VOTES = os.path.join(DATA_DIR, "votes_baoki.csv")
PATH_TO_GRANTS = os.path.join(DATA_DIR, "all-allo-rounds.csv")
PATH_TO_PROJECTS = os.path.join(DATA_DIR, "projects_QmQurt.csv")

# load data
df_votes = pd.read_csv(PATH_TO_VOTES)
df_grants = pd.read_csv(PATH_TO_GRANTS)
df_application = pd.read_csv(PATH_TO_PROJECTS)
# Lowercase all addresses because flipside api return lowercase address
df_grants['Round ID'] = df_grants['Round ID'].str.lower()
str_columns_votes = ['id', 'transaction', 'projectId', 'roundId', 'voter', 'grantAddress']
df_votes[str_columns_votes] = df_votes[str_columns_votes].applymap(lambda x: x.lower())

str_columns_application = ['id', 'roundId', 'metadata.application.round', 'metadata.application.recipient']
df_application[str_columns_application] = df_application[str_columns_application].applymap(lambda x: str(x).lower())

round_id = df_grants[df_grants['Round name'] == 'Web3 Community and Education']['Round ID'].values[0]
array_unique_address = df_votes[df_votes['roundId'] == round_id]['voter'].unique()

array_unique_address = np.char.lower(array_unique_address.astype(str))

# %%
from sbutils import LoadData

# Load data
data_loader = LoadData.LoadData(PATH_TO_EXPORT)
df_tx = data_loader.create_df_tx('ethereum')

# %%
len(array_unique_address)
# Out:
# 1023

# %%
df_tx.EOA.nunique()
# Out:
# 1022

# %%
c = np.setxor1d(array_unique_address, df_tx.EOA.values)
c
# Out:
# array(['0x4a35674727c44cf4375d80c6171281ba2f764213'], dtype=object)

# %% [markdown]
# ## Looking at a specific address donation

# %% [markdown]
# I don't know why that address is not retrieved by the API, but it is a voter and had some interesting patterns to explore.
# The address is: 0x4a35674727c44cf4375d80c6171281ba2f764213 voted to many projects by giving exactly the same amount to all of them. Let see:

# %%
suspicious_add = c[0]

# %%
df_vote_sus = df_votes[df_votes.voter== suspicious_add]
print(f'Number of votes: {len(df_vote_sus)}')
print(f'Number of unique projects: {df_vote_sus.projectId.nunique()}')
print(f'Number of unique grants: {df_vote_sus.grantAddress.nunique()}')
# Out:
# Number of votes: 48
# Number of unique projects: 48
# Number of unique grants: 47

# %% [markdown]
# Which project received the most votes from this address?

# %%
df_vote_sus['grantAddress'].value_counts().head(3)
# Out:
# grantAddress
# 0xb6e780438882f2daa11da0972807f4d12166af8b    2
# 0x486c853c41885d9c1edb57c423853fc4fbc60769    1
# 0xc36e4889a820bd8089a8ad226ee9d0c703aed314    1
# Name: count, dtype: int64

# %%
# look at what is the project of the grant
suspicious_add = df_vote_sus['grantAddress'].value_counts().index[0]
df_application[df_application['metadata.application.recipient'] == suspicious_add]['metadata.application.project.title']
# Out:
# 268    Impact DAOs Research + Podcast + Book : Impact...
# 337    Impact DAO Course + IRL/Online Events: Educati...
# 687    Impact DAOs Research + Podcast + Book : Impact...
# Name: metadata.application.project.title, dtype: object

# %% [markdown]
# I find it very suspicious that this project "Impact DAO" applied for a grant with two subprojects. It would be interesting to explore how much common voter overlap there is between the two subprojects.

# %%
df_votes[df_votes['grantAddress'] == suspicious_add].groupby('projectId').count()
# Out:
#                                                     id  transaction
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...  19           19  \
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...  28           28
#
#                                                     blockNumber
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...           19  \
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...           28
#
#                                                     applicationId  roundId
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...             19       19  \
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...             28       28
#
#                                                     voter  grantAddress
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...     19            19  \
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...     28            28
#
#                                                     token  amount  amountUSD
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...     19      19         19  \
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...     28      28         28
#
#                                                     amountRoundToken
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...                19  \
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...                28
#
#                                                     createdAt
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...         19
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...         28

# %%
df_votes[df_votes['grantAddress'] == suspicious_add].groupby('projectId')['voter'].nunique()
# Out:
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53a386a8e1278016f6a50    18
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad5cc66b547d88cb93200    27
# Name: voter, dtype: int64

# %%
df_votes[df_votes['grantAddress'] == suspicious_add].groupby('projectId')['amount'].describe()
# Out:
#                                                    count unique
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...    19     12  \
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...    28     15
#
#                                                                  top freq
# projectId
# 0x3e7af275e7342f380ce8182e2f1e19ecbf32086974f53...  5000000000000000    3
# 0xa35e52635d40be090a49c587e58fab7410c30b9cff7ad...  1000000000000000    6

# %% [markdown]
# The average donation is 1$ in both cases! 19 votes for 19$ and 28 votes for 28$.

# %% [markdown]
# This project is very suspicious and should proably be squelched.

# %% [markdown]
# ## Computing legos booleans

# %%
from sblegos.TransactionAnalyser import TransactionAnalyser as txa
tx_analyser = txa(df_tx, df_address=pd.DataFrame(np.intersect1d(df_tx.EOA.unique(), array_unique_address)))

# %%
df_matching_address = pd.DataFrame(df_tx.EOA.unique(), columns=["address"])
df_matching_address.head(2)
# Out:
#                                       address
# 0  0x0010e3bce7e7d5890849fa2bb2681174f4352bc4
# 1  0x00173c4cb23e6d876fcb036ba954a2f9cfcafa19

# %% [markdown]
# Compute the boolean

# %%
df_matching_address['seed_same_naive'] = df_matching_address.loc[:, 'address'].apply(lambda x : tx_analyser.has_same_seed_naive(x))
df_matching_address['seed_same'] = df_matching_address.loc[:, 'address'].apply(lambda x : tx_analyser.has_same_seed(x))
df_matching_address['seed_suspicious'] = df_matching_address.loc[:, 'seed_same_naive'].ne(df_matching_address.loc[:, 'seed_same'])
df_matching_address['less_5_tx'] = df_matching_address.loc[:, 'address'].apply(lambda x : tx_analyser.has_less_than_n_transactions(x, 5))
df_matching_address['less_10_tx'] = df_matching_address.loc[:, 'address'].apply(lambda x : tx_analyser.has_less_than_n_transactions(x, 10))
df_matching_address['interacted_other_ctbt'] = df_matching_address.loc[:, 'address'].apply(lambda x : tx_analyser.has_interacted_with_other_contributor(x))

# %%
print(f'Number of voters: {len(df_matching_address)}')
# Out:
# Number of voters: 1022

# %%
df_matching_address.sum()
# Out:
# address                  0x0010e3bce7e7d5890849fa2bb2681174f4352bc40x00...
# seed_same_naive                                                        609
# seed_same                                                              617
# seed_suspicious                                                         14
# less_5_tx                                                              209
# less_10_tx                                                             283
# interacted_other_ctbt                                                  211
# dtype: object

# %% [markdown]
# ### Investigating the boolean seed suspicious

# %%
df_matching_address[df_matching_address['seed_suspicious'] == True]
# Out:
#                                          address  seed_same_naive  seed_same
# 19    0x04afa8026bff7e97443f4efd6f96c6f2ff6d4ec9            False       True  \
# 229   0x3a42f1dcc218b0ee48966954208c9c4acbc04d89            False       True
# 422   0x6b5918d8ef9094679f4b4e1bf397a66ea411b118            False       True
# 508   0x84f1cb27f0822135708aa879bbf04767af18019a            False       True
# 529   0x8a2ec4cc1d731bbace15fc5d234690a0788610a7             True      False
# 579   0x975a0e1bf2fdf3f4e5ba31b6c5774e73573b6b65            False       True
# 582   0x978eb534b26cb8749d352a2c94ec21e659e4248d             True      False
# 606   0x9d5c545d329454ab4ea9ff49a4e77985b9599232            False       True
# 673   0xac4ddaf8fbffba0f1e8c7619720335fd4f03eacd             True      False
# 774   0xc28064b875ae25f9a2ca28c08f116a5c26229f69            False       True
# 833   0xd15be984f5e58358b905b19e8fdafced86954970            False       True
# 910   0xe51200a4d161935fc311ed8a0401feb1abf20e3a            False       True
# 963   0xf11704511975cc5908f6dbd89be922f5c86c1055            False       True
# 1006  0xfbca78474a09e2bf3543f4fc1037152ea2c6c32d            False       True
#
#       seed_suspicious  less_5_tx  less_10_tx  interacted_other_ctbt
# 19               True      False       False                   True
# 229              True      False       False                  False
# 422              True      False       False                  False
# 508              True      False       False                   True
# 529              True       True        True                   True
# 579              True      False       False                  False
# 582              True      False       False                   True
# 606              True      False       False                   True
# 673              True      False       False                   True
# 774              True      False       False                  False
# 833              True      False       False                   True
# 910              True      False       False                  False
# 963              True      False       False                  False
# 1006             True      False       False                   True

# %%
projects_voted = df_votes[df_votes['voter'] == '0xc28064b875ae25f9a2ca28c08f116a5c26229f69']
print(f'Number of votes {projects_voted.shape[0]} Number of projects voted: {projects_voted.grantAddress.nunique()}')
# Merge the project the user voted for and the projects 
projects_voted.merge(df_application, left_on='grantAddress', right_on='metadata.application.recipient', how='left').drop_duplicates(subset='grantAddress').loc[:, ['grantAddress', 'metadata.application.project.title', 'status', 'metadata.application.round']].reset_index(drop=True)
# Out:
# Number of votes 16 Number of projects voted: 16
#                                   grantAddress
# 0   0x10666d9c6295e838d3b8b84ffcc97d62ef7e6120  \
# 1   0x11ee133a1408fe2d7c62296d7eb33f234b774503
# 2   0x7d658841f8ba93299970f6e765c2ce205f1e70dd
# 3   0xb67fd6f4b908d702c2cf0e2b9d30d52d4ea5b2bc
# 4   0x713bc00d1df5c452f172c317d39eff71b771c163
# 5   0xdecf6615152ac768bfb688c4ef882e35debe08ac
# 6   0x187089b65520d2208ab93fb471c4970c29eaf929
# 7   0xb352bb4e2a4f27683435f153a259f1b207218b1b
# 8   0xb7081fd06e7039d198d10a8b72b824e60c1b1e16
# 9   0x52277e5cf8df8ef51d9bd37d8d7553a72d378bef
# 10  0x23ada6e6a9e9d4ecddd185e3ec353163bceebf2a
# 11  0x00de4b13153673bcae2616b67bf822500d325fc3
# 12  0x4d9339dd97db55e3b9bcbe65de39ff9c04d1c2cd
# 13  0x629e715db365fdbac0a61330cbf256237dccdcb9
# 14  0x7ad6e69fce7b87e0ada3f5c87e5f3705278f6ec7
# 15  0x63c3742f92b6144876dc9a36ac373d0346f4f2e3
#
#                    metadata.application.project.title    status
# 0   Inverter Network - Fund and build in web 3 wit...  APPROVED  \
# 1     dm3 protocol - the interoperability initiative   REJECTED
# 2                                           Loanshark  APPROVED
# 3                                                ECHO  APPROVED
# 4                                       Kakarot zkEVM  APPROVED
# 5             Rhino Review - Ethereum Staking Journal  APPROVED
# 6                                       Ape Framework  APPROVED
# 7                                            eth.limo  REJECTED
# 8                                           Otterscan  APPROVED
# 9                                   Trustless zkMafia  APPROVED
# 10  PLUME: Pseudonymously Linked Unique Message En...  APPROVED
# 11                                  Greenpill Podcast  APPROVED
# 12                                             Giveth  APPROVED
# 13                                              Share  APPROVED
# 14                                            FusionX  APPROVED
# 15                                    Pulsar Protocol  APPROVED
#
#                     metadata.application.round
# 0   0x12bb5bbbfe596dbc489d209299b8302c3300fa40
# 1   0x12bb5bbbfe596dbc489d209299b8302c3300fa40
# 2   0x12bb5bbbfe596dbc489d209299b8302c3300fa40
# 3   0x12bb5bbbfe596dbc489d209299b8302c3300fa40
# 4   0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094
# 5   0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094
# 6   0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094
# 7   0x12bb5bbbfe596dbc489d209299b8302c3300fa40
# 8   0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094
# 9   0x274554eb289004e15a7679123901b7f070dda0fa
# 10  0x274554eb289004e15a7679123901b7f070dda0fa
# 11  0xaa40e2e5c8df03d792a52b5458959c320f86ca18
# 12  0x12bb5bbbfe596dbc489d209299b8302c3300fa40
# 13  0x9c3b81967eafba0a451e324417dd4f3f353b997b
# 14  0xf1c021df6dc6b2dc2e5a837cdfddc2f42503233b
# 15  0xf1c021df6dc6b2dc2e5a837cdfddc2f42503233b

# %% [markdown]
# Some of the projects he donated to are in the list of Rejected projects showing that this address is indeed a sybil. And may have contributed to ohter fraudulent projects.

# %% [markdown]
# - Pulsar is not very active and is forked code for the most part
# - Fusion not very active on github but has a lot of activity on twitter
# - Share suspicious Github with no activity, twitter does not exists: suspicious
#
# Other projects are ok

# %%
projects_voted = df_votes[df_votes['voter'] == '0x61ffe691821291d02e9ba5d33098adcee71a3a17']
print(f'Number of votes {projects_voted.shape[0]} Number of projects voted: {projects_voted.grantAddress.nunique()}')
# Merge the project the user voted for and the projects 
projects_voted.merge(df_application, left_on='grantAddress', right_on='metadata.application.recipient', how='left').drop_duplicates(subset='grantAddress').loc[:, ['grantAddress', 'metadata.application.project.title']].reset_index(drop=True)
# Out:
# Number of votes 3 Number of projects voted: 3
#                                  grantAddress
# 0  0x5514f4a2bc7194664b12a48e238876aa53140350  \
# 1  0x53390590476dc98860316e4b46bb9842af55efc4
# 2  0x4cd6b4503d02973d78cff59c9c56f5f378688274
#
#                   metadata.application.project.title
# 0                                   Voting Contracts
# 1                                           DAppNode
# 2  Mechanism Institute: Democratizing Cryptoecono...

# %%
projects_voted = df_votes[df_votes['voter'] == '0xe51200a4d161935fc311ed8a0401feb1abf20e3a']
print(f'Number of votes {projects_voted.shape[0]} Number of projects voted: {projects_voted.grantAddress.nunique()}')
# Merge the project the user voted for and the projects 
projects_voted.merge(df_application, left_on='grantAddress', right_on='metadata.application.recipient', how='left').drop_duplicates(subset='grantAddress').loc[:, ['grantAddress', 'metadata.application.project.title']].reset_index(drop=True)
# Out:
# Number of votes 2 Number of projects voted: 2
#                                  grantAddress
# 0  0x2f6c8f867df4e49e4fb24741c414f315e266c21b  \
# 1  0xba97f51b1b097ce1ea43cf941cd62dfbcd70cae3
#
#   metadata.application.project.title
# 0                      Ethereum Lima
# 1                           ETH Kipu

# %% [markdown]
# The boolean seed suspicious is not relevant for that round we will not use it for the analysis.

# %% [markdown]
# ### Computing the new dex interaction score
# It was investigated in another notebook

# %%
def get_interacted_address(from_address, to_address, address):
    if from_address == address:
        return to_address
    else:
        return from_address

def count_interaction_with_any(tx_analyser, address, array_address):
    """
    Return an integer of the number of interactions with the addresses in the array_address
    Parameters
    ----------
    address : str
        The address to check

    Returns
    -------
    count_interaction_with_any : int
        The number of interactions with the addresses in the array_address
    """
    tx_analyser.set_group_by_sorted_EOA()

    df = tx_analyser.gb_EOA_sorted.get_group(address)
    address_interacted = df.apply(lambda x: get_interacted_address(x['from_address'], x['to_address'], address), axis=1)
    tx_boolean_interacted = address_interacted.isin(array_address)
    return tx_boolean_interacted.sum()

def has_interacted_with_any(tx_analyser, address, array_address):
    """
    Return a boolean whether the address has interacted with any address in the array_address
    Parameters
    ----------
    address : str
        The address to check

    Returns
    -------
    has_interacted_with_any : bool
        True if the address has interacted with one or more of the addresses in the array_address
    """
    count_interaction_with_any = count_interaction_with_any(tx_analyser, address, array_address)
    return count_interaction_with_any > 0

# %%
label_query = '''
SELECT ADDRESS, CREATOR, LABEL_TYPE, ADDRESS_NAME, PROJECT_NAME
FROM crosschain.core.address_labels 
WHERE BLOCKCHAIN='ethereum'
AND LABEL_SUBTYPE = 'pool' 
;'''
df_label = flipside_api.execute_query(label_query)

# %%
# extract all the pool addresses
array_pool_address = df_label['address'].unique()

# %%
tx_analyser.set_group_by_sorted_EOA()

# %%
# Compute the number of interactions with any of the pools for each address
df_matching_address['count_interaction_with_pool'] = df_matching_address['address'].apply(lambda x: count_interaction_with_any(tx_analyser, x, array_pool_address))

# %%
(df_matching_address['count_interaction_with_pool'] > 0).sum() / len(df_matching_address)
# Out:
# 0.32093933463796476

# %%
label_query = '''
SELECT DISTINCT(LABEL_SUBTYPE)
FROM crosschain.core.address_labels 
WHERE BLOCKCHAIN='ethereum'
;'''
df_distinct_labels = flipside_api.execute_query(label_query)

# %%
df_distinct_labels.label_subtype.unique()
# Out:
# array(['strategy', 'chadmin', 'router', 'multisig', 'airdrop_contract',
#        'nf_token_contract', 'token_distribution', 'nf_position_manager',
#        'donation_address', 'mining_pool', 'deposit_wallet',
#        'staking_contract', 'pool', 'token_contract', 'bridge',
#        'mint_burn', 'mint_contract', 'contract_deployer', 'marketplace',
#        'foundation', 'vault', 'voting', 'cold_wallet', 'reserve',
#        'swap_router', 'hot_wallet', 'toxic', 'fee_wallet', 'governance',
#        'general_contract', 'swap_contract', 'distributor_cex', 'escrow',
#        'rewards', 'dao', 'treasury', 'token_sale', 'oracle',
#        'aggregator_contract'], dtype=object)

# %% [markdown]
# From these tags lets flag any address that have interacted with a toxic wallet

# %%
label_query = '''
SELECT ADDRESS, CREATOR, LABEL_TYPE, ADDRESS_NAME, PROJECT_NAME
FROM crosschain.core.address_labels 
WHERE BLOCKCHAIN='ethereum'
AND LABEL_SUBTYPE = 'toxic'
;'''
df_toxic = flipside_api.execute_query(label_query)

# %%
df_toxic.shape
# Out:
# (4857, 6)

# %%
# Compute the number of interactions with any of the scam for each address
df_matching_address['count_interaction_with_toxic'] = df_matching_address['address'].apply(lambda x: count_interaction_with_any(tx_analyser, x, df_toxic['address'].unique()))

# %%
print(f'Percentage of addresses that have interacted with a toxic address: {int((df_matching_address["count_interaction_with_toxic"] > 0).sum() / len(df_matching_address) *100)}%')
# Out:
# Percentage of addresses that have interacted with a toxic address: 1%

# %%
tag_query = '''
SELECT DISTINCT(TAG_TYPE)
FROM crosschain.core.address_tags 
WHERE BLOCKCHAIN='ethereum'
;'''
df_distinct_tags = flipside_api.execute_query(tag_query)

# %%
df_distinct_tags.tag_type.values
# Out:
# array(['contract', 'Balancer Delegates', 'wallet', 'activity', 'cex',
#        'chainlink oracle', 'Aave Delegates', 'NFT', 'nft', 'dex'],
#       dtype=object)

# %% [markdown]
# I found the tag_name "airdrop master" could be interesting

# %%
query_airdrop_master = '''
SELECT BLOCKCHAIN, CREATOR, ADDRESS, TAG_NAME
FROM crosschain.core.address_tags 
WHERE BLOCKCHAIN='ethereum'
AND TAG_NAME = 'airdrop master'
;
'''
df_airdrop_master = flipside_api.execute_query(query_airdrop_master)

# %%
# Compute the number of interactions with any of the aidrop for each address
df_matching_address['count_interaction_with_airdrop_m'] = df_matching_address['address'].apply(lambda x: count_interaction_with_any(tx_analyser, x, df_airdrop_master['address'].unique()))
print(f'Percentage of addresses that interacted with airdrop master: {int((df_matching_address["count_interaction_with_airdrop_m"] > 0).sum() / len(df_matching_address) * 100)}%')
# Out:
# Percentage of addresses that interacted with airdrop master: 19%

# %%
# Boolean whether the address is a aidrop master
df_matching_address['is_airdrop_master'] = df_matching_address['address'].apply(lambda x: x in df_airdrop_master['address'].unique()) 
print(f'Percentage of addresses that are airdrop master: {int((df_matching_address["is_airdrop_master"]).sum() / len(df_matching_address) * 100)}%')
# Out:
# Percentage of addresses that are airdrop master: 6%

# %%
sql_query_tornado = '''
SELECT DISTINCT PROJECT_NAME, ADDRESS
FROM crosschain.core.address_labels 
WHERE BLOCKCHAIN='ethereum'
AND PROJECT_NAME LIKE '%tornado%'
;
'''
df_tornado = flipside_api.execute_query(sql_query_tornado)

# %%
# Count the number of interactions with tornado
df_matching_address['count_interaction_with_tornado'] = df_matching_address['address'].apply(lambda x: count_interaction_with_any(tx_analyser, x, df_tornado['address'].unique()))
print(f'Percentage of addresses that interacted with tornado: {int((df_matching_address["count_interaction_with_tornado"] > 0).sum() / len(df_matching_address) * 100)}%')
# Out:
# Percentage of addresses that interacted with tornado: 3%

# %%
# Count the number of time the address interatec with disperse contract: '0xD152f549545093347A162Dce210e7293f1452150'
df_matching_address['count_interaction_with_disperse'] = df_matching_address['address'].apply(lambda x: count_interaction_with_any(tx_analyser, x, [str.lower('0xD152f549545093347A162Dce210e7293f1452150')]))
print(f'Percentage of addresses that interacted with disperse: {int((df_matching_address["count_interaction_with_disperse"] > 0).sum() / len(df_matching_address) * 100)}%')
# Out:
# Percentage of addresses that interacted with disperse: 1%

# %%
df_matching_address.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])
# Out:
#        count_interaction_with_pool  count_interaction_with_toxic
# count                  1022.000000                    1022.00000  \
# mean                      6.946184                       0.02544
# std                      38.091056                       0.23281
# min                       0.000000                       0.00000
# 10%                       0.000000                       0.00000
# 25%                       0.000000                       0.00000
# 50%                       0.000000                       0.00000
# 75%                       2.000000                       0.00000
# 90%                      12.000000                       0.00000
# max                     742.000000                       5.00000
#
#        count_interaction_with_airdrop_m  count_interaction_with_tornado
# count                       1022.000000                     1022.000000  \
# mean                           1.773973                        0.103718
# std                            7.696927                        0.830966
# min                            0.000000                        0.000000
# 10%                            0.000000                        0.000000
# 25%                            0.000000                        0.000000
# 50%                            0.000000                        0.000000
# 75%                            0.000000                        0.000000
# 90%                            3.000000                        0.000000
# max                           96.000000                       18.000000
#
#        count_interaction_with_disperse
# count                      1022.000000
# mean                          0.078278
# std                           0.901483
# min                           0.000000
# 10%                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# 90%                           0.000000
# max                          16.000000

# %%
df_matching_address['has_interaction_toxic'] = df_matching_address['count_interaction_with_toxic'] > 0
df_matching_address['has_no_pool_interaction'] = df_matching_address['count_interaction_with_pool'] < 6
df_matching_address['has_interaction_airdrop_m'] = df_matching_address['count_interaction_with_airdrop_m'] > 0
df_matching_address['has_interaction_tornado'] = df_matching_address['count_interaction_with_tornado'] > 0
df_matching_address['has_interaction_disperse'] = df_matching_address['count_interaction_with_disperse'] > 0

# %%
boolean_features = ['has_interaction_toxic', 'has_no_pool_interaction', 'has_interaction_airdrop_m', 'has_interaction_tornado', 'has_interaction_disperse', 'is_airdrop_master', 'interacted_other_ctbt', 'less_10_tx', 'less_5_tx']

# %%
df_matching_address[boolean_features].sum()
# Out:
# has_interaction_toxic         18
# has_no_pool_interaction      870
# has_interaction_airdrop_m    200
# has_interaction_tornado       32
# has_interaction_disperse      17
# is_airdrop_master             70
# interacted_other_ctbt        211
# less_10_tx                   283
# less_5_tx                    209
# dtype: int64

# %%
(df_matching_address[boolean_features].sum(axis=1) > 2).sum()
# Out:
# 305

# %%
df_matching_address['count_flags'] = df_matching_address[boolean_features].sum(axis=1)

# %%
df_matching_address['suspicious_1'] = df_matching_address['count_flags'] > 2

# %%
df_suspicious_1 = df_matching_address[df_matching_address['suspicious_1'] == True]

# %% [markdown]
# ### Investigating the grants receiving the most votes from the flagged addresses

# %%
df_vote_sus1 = df_votes[df_votes['voter'].isin(df_suspicious_1['address'])]

# %%
print(f'Number of votes {df_vote_sus1.shape[0]} Number of projects voted: {df_vote_sus1.grantAddress.nunique()}')
# Merge the project the user voted for and the projects 
gr_sus = df_vote_sus1['grantAddress'].value_counts().reset_index().merge(df_application, left_on='grantAddress', right_on='metadata.application.recipient', how='left').drop_duplicates(subset='grantAddress').loc[:, ['grantAddress', 'metadata.application.project.title', 'count', 'roundId', 'status']].reset_index(drop=True)
# Out:
# Number of votes 1304 Number of projects voted: 395

# %%
gr_sus.head(30)
# Out:
#                                   grantAddress
# 0   0xc36e4889a820bd8089a8ad226ee9d0c703aed314  \
# 1   0x4adc8cc149a03f44386bee80bab36f9e8022b195
# 2   0x8110d1d04ac316fdcace8f24fd60c86b810ab15a
# 3   0x18aa467e40e1defb1956708830a343c1d01d3d7c
# 4   0x4d9339dd97db55e3b9bcbe65de39ff9c04d1c2cd
# 5   0xda3dddae8119644f8be18c7afd16850b02a4c841
# 6   0x3a5bd1e37b099ae3386d13947b6a90d97675e5e3
# 7   0x1dd8ec683e8b53c57ba5a01c5d2f866a3fbd3ce8
# 8   0xd8eab52bccf6307a4579ab868b42eee0eb5492ed
# 9   0x57e6cf96a2e99a3fdaa79acc3a14fc9be1eabc03
# 10  0x4b8810b079eb22ecf2d1f75e08e0abbd6fd87dbf
# 11  0x3d2c7d934d0b0f2979de988e0092aa8c2ccfc638
# 12  0xc8d65e1bd67f16522e3117b980e1c9d2caeb9dc3
# 13  0x08a3c2a819e3de7aca384c798269b3ce1cd0e437
# 14  0xffbd35255008f86322051f2313d4b343540e0e00
# 15  0x0b7246ef74ca7b37fdc3d15be4f0b49876622f95
# 16  0x5ead82e959d8218f6003526ab8d457972b679c41
# 17  0x0035cc37599241d007d0aba1fb931c5fa757f7a1
# 18  0x53390590476dc98860316e4b46bb9842af55efc4
# 19  0x6c5a2688c83c806150ca9dd0b2f10f16f8f1c33e
# 20  0xb604cda24cca1838428be7d40fcd830451c23a0e
# 21  0xefedaf9c07e6eb56bb8f82f30018e4461b1c5f4c
# 22  0x73dce9348a03975415c6fa5296e71c1abae61407
# 23  0x929e1b374fb07486c9a64570e5bda99383f48785
# 24  0x0442a9abbc93058a873c371f21cc366338254a88
# 25  0x5afc7720b161788f9d833555b7ebc3274fd98da1
# 26  0xe126b3e5d052f1f575828f61feba4f4f2603652a
# 27  0x9d4e94db689bc471e45b0a18b7bda36fccec9c3b
# 28  0x57ea12a3a8e441f5fe7b1f3af1121097b7d3b6a8
# 29  0xfbca78474a09e2bf3543f4fc1037152ea2c6c32d
#
#                   metadata.application.project.title  count
# 0                                  Crypto Babes Club    173  \
# 1                                             Unitap     17
# 2                                      Commons Stack     14
# 3                                           JediSwap     12
# 4                                             Giveth     11
# 5                   ETH Venezuela Community Projects     11
# 6                                            Lenster     11
# 7                  Help Protect the Internet Archive     10
# 8                                   Ethereum Uruguay     10
# 9                                The Neptune Project     10
# 10          BrightID 🔆 Universal Proof of Uniqueness      9
# 11                                           Revolte      9
# 12  Pairwise: Tinder UX for web3 community signaling      9
# 13                                         DefiLlama      9
# 14                                       Gravity DAO      9
# 15                                            Praise      8
# 16                               Ethereum Costa Rica      8
# 17                                         EVMcrispr      8
# 18                                          DAppNode      7
# 19                                            L2BEAT      7
# 20                                      Trusted Seed      7
# 21                                         Web3beach      7
# 22                                             zkBob      7
# 23                                             Solow      7
# 24                                          Urbanika      7
# 25                                            POAPin      7
# 26       Revoke.cash - Helping you stay safe in web3      7
# 27                                      beaconcha.in      7
# 28                                             Umbra      7
# 29                                          Atlantis      6
#
#                                        roundId    status
# 0   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 1   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 2   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 3   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 4   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 5   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 6   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 7   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 8   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 9   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 10  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 11  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 12  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 13  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 14  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 15  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 16  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 17  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 18  0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094  APPROVED
# 19  0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094  APPROVED
# 20  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 21  0x421510312c40486965767be5ea603aa8a5707983  APPROVED
# 22  0x274554eb289004e15a7679123901b7f070dda0fa  APPROVED
# 23  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 24  0x421510312c40486965767be5ea603aa8a5707983  APPROVED
# 25  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 26  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 27  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 28  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 29  0x421510312c40486965767be5ea603aa8a5707983  APPROVED

# %% [markdown]
# Upchain twitter handle does not exists but the repo is very active Suspicious?
#
# - Seoul bound is either very new or suspicious
# - Gravity DAO old project not sure it is still active
#
# Other projects are not suspicious

# %% [markdown]
# ### Look at the addresses with many flags

# %%
df_matching_address[boolean_features].sum()
# Out:
# has_interaction_toxic         18
# has_no_pool_interaction      870
# has_interaction_airdrop_m    200
# has_interaction_tornado       32
# has_interaction_disperse      17
# is_airdrop_master             70
# interacted_other_ctbt        211
# less_10_tx                   283
# less_5_tx                    209
# dtype: int64

# %% [markdown]
# We are going to review the addresses that have at least 1 flag:
# - has_intercation_toxic
# - has_interaction_tornado
# - has_interaction_disperse
# - has_interaction_airdrop_master
# - is airdrop master

# %%
interaction_bool = ['has_interaction_toxic', 'has_interaction_airdrop_m', 'has_interaction_tornado', 'has_interaction_disperse', 'is_airdrop_master']

# %%
df_interact_sus = df_matching_address[df_matching_address[interaction_bool].sum(axis=1) > 0]
print(f'Number of addresses that interacted with a suspicious contract or address: {df_interact_sus.shape[0]}')
# Out:
# Number of addresses that interacted with a suspicious contract or address: 226

# %%
df_vote_interact_sus = df_votes[df_votes['voter'].isin(df_interact_sus['address'])]

# %%
print(f'Number of votes {df_vote_sus1.shape[0]} Number of projects voted: {df_vote_sus1.grantAddress.nunique()}')
# Merge the project the user voted for and the projects 
gr_sus = df_vote_interact_sus['grantAddress'].value_counts().reset_index().merge(df_application, left_on='grantAddress', right_on='metadata.application.recipient', how='left').drop_duplicates(subset='grantAddress').loc[:, ['grantAddress', 'metadata.application.project.title', 'count', 'roundId', 'status']].reset_index(drop=True)
# Out:
# Number of votes 1304 Number of projects voted: 395

# %%
gr_sus.sort_values(by='count', ascending=False).head(30)
# Out:
#                                   grantAddress
# 0   0x3a5bd1e37b099ae3386d13947b6a90d97675e5e3  \
# 1   0x18aa467e40e1defb1956708830a343c1d01d3d7c
# 2   0x08a3c2a819e3de7aca384c798269b3ce1cd0e437
# 3   0x4d9339dd97db55e3b9bcbe65de39ff9c04d1c2cd
# 4   0xe126b3e5d052f1f575828f61feba4f4f2603652a
# 5   0x8110d1d04ac316fdcace8f24fd60c86b810ab15a
# 6   0x99b36fdbc582d113af36a21eba06bfeab7b9be12
# 7   0x4b8810b079eb22ecf2d1f75e08e0abbd6fd87dbf
# 8   0x4adc8cc149a03f44386bee80bab36f9e8022b195
# 11  0xb352bb4e2a4f27683435f153a259f1b207218b1b
# 9   0x9d727911b54c455b0071a7b682fcf4bc444b5596
# 10  0x00de4b13153673bcae2616b67bf822500d325fc3
# 12  0x6c5a2688c83c806150ca9dd0b2f10f16f8f1c33e
# 13  0x01d79bceaeaadfb8fd2f2f53005289cfcf483464
# 14  0x7d658841f8ba93299970f6e765c2ce205f1e70dd
# 15  0xda3dddae8119644f8be18c7afd16850b02a4c841
# 18  0x53390590476dc98860316e4b46bb9842af55efc4
# 19  0x0eb2ab241210900aeac2fba054dd605355fe2490
# 17  0x743b8e21eb7bd3cb81e521b5f3e7f3c6fbe61d33
# 16  0x57ea12a3a8e441f5fe7b1f3af1121097b7d3b6a8
# 20  0xb604cda24cca1838428be7d40fcd830451c23a0e
# 21  0xb6e780438882f2daa11da0972807f4d12166af8b
# 22  0x4af147188bfe1c02d18d752ed5e473d8394f2300
# 23  0x73dce9348a03975415c6fa5296e71c1abae61407
# 24  0xc8d65e1bd67f16522e3117b980e1c9d2caeb9dc3
# 25  0x6b5918d8ef9094679f4b4e1bf397a66ea411b118
# 26  0x9531c059098e3d194ff87febb587ab07b30b1306
# 27  0x713bc00d1df5c452f172c317d39eff71b771c163
# 28  0xd39d6d3f7433a0cabd90c0ea74d76da29b718314
# 29  0xf29ff96aaea6c9a1fba851f74737f3c069d4f1a9
#
#                    metadata.application.project.title  count
# 0                                             Lenster     35  \
# 1                                            JediSwap     29
# 2                                           DefiLlama     26
# 3                                              Giveth     26
# 4         Revoke.cash - Helping you stay safe in web3     26
# 5                                       Commons Stack     25
# 6       Taho - Open Source and Community Owned Wallet     23
# 7            BrightID 🔆 Universal Proof of Uniqueness     22
# 8                                              Unitap     21
# 11                                           eth.limo     20
# 9                                             ZachXBT     20
# 10                                  Greenpill Podcast     20
# 12                                             L2BEAT     19
# 13                                           Lenstube     19
# 14                                          Loanshark     18
# 15                   ETH Venezuela Community Projects     18
# 18                                           DAppNode     17
# 19                                        Buidl Guidl     17
# 17                                  GreenPill Global      17
# 16                                              Umbra     17
# 20                                       Trusted Seed     16
# 21  Impact DAOs Research + Podcast + Book : Impact...     16
# 22  Fileverse – because Notion & Gsuite are centra...     16
# 23                                              zkBob     15
# 24   Pairwise: Tinder UX for web3 community signaling     15
# 25                            Infinite Garden Library     15
# 26                                              rotki     15
# 27                                      Kakarot zkEVM     15
# 28                                            Metagov     15
# 29                                     Protocol Guild     15
#
#                                        roundId    status
# 0   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 1   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 2   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 3   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 4   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 5   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 6   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 7   0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 8   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 11  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  REJECTED
# 9   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 10  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 12  0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094  APPROVED
# 13  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 14  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 15  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 18  0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094  APPROVED
# 19  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 17  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 16  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 20  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 21  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 22  0x9c3b81967eafba0a451e324417dd4f3f353b997b  APPROVED
# 23  0x274554eb289004e15a7679123901b7f070dda0fa  APPROVED
# 24  0x12bb5bbbfe596dbc489d209299b8302c3300fa40  APPROVED
# 25  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 26  0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094  APPROVED
# 27  0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094  APPROVED
# 28  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 29  0xdf22a2c8f6ba9376ff17ee13e6154b784ee92094  APPROVED

# %% [markdown]
# No projects look suspicious in the top 30 by contribution

# %% [markdown]
# ### Investigating more in details the type of donations made by the flagged addresses

# %%
# look at the average donation in USD
gb_donation_usd = df_vote_interact_sus.groupby('voter').describe()['amountUSD']

# %%
gb_donation_usd[gb_donation_usd['count'] == 1].sort_values(by='count', ascending=True)
# Out:
#                                             count        mean  std
# voter
# 0x008c9f31533dd2a327d0ff28b6fe87194de1e3d3    1.0    5.997155  NaN  \
# 0xa0839d50d601c0ce86677a03739f802fe614ba22    1.0   19.997351  NaN
# 0xa009881d1ecddb62a2e15f0ef19c482dd2df1c3a    1.0   92.636609  NaN
# 0x9b278aaef429cc4728e594f8fa0fbfe78e72cc26    1.0    1.138289  NaN
# 0x921f80499a00ac6e95aae0daa411d338f41d5da2    1.0    9.528923  NaN
# ...                                           ...         ...  ...
# 0x40f9bf922c23c43acdad71ab4425280c0ffbd697    1.0  200.691627  NaN
# 0x3ffc07ed6a65e379e39bef93e713ee3ff77a56e4    1.0   36.972994  NaN
# 0x3e48830bf4415311d13c3c89a0e315ee7398d114    1.0    3.792925  NaN
# 0x71f84aa585e1eda8852dad8dff3a69d114366dba    1.0    9.734560  NaN
# 0xff56ec56a405716accaa4e6c54aef7fa2948192e    1.0    9.247645  NaN
#
#                                                    min         25%
# voter
# 0x008c9f31533dd2a327d0ff28b6fe87194de1e3d3    5.997155    5.997155  \
# 0xa0839d50d601c0ce86677a03739f802fe614ba22   19.997351   19.997351
# 0xa009881d1ecddb62a2e15f0ef19c482dd2df1c3a   92.636609   92.636609
# 0x9b278aaef429cc4728e594f8fa0fbfe78e72cc26    1.138289    1.138289
# 0x921f80499a00ac6e95aae0daa411d338f41d5da2    9.528923    9.528923
# ...                                                ...         ...
# 0x40f9bf922c23c43acdad71ab4425280c0ffbd697  200.691627  200.691627
# 0x3ffc07ed6a65e379e39bef93e713ee3ff77a56e4   36.972994   36.972994
# 0x3e48830bf4415311d13c3c89a0e315ee7398d114    3.792925    3.792925
# 0x71f84aa585e1eda8852dad8dff3a69d114366dba    9.734560    9.734560
# 0xff56ec56a405716accaa4e6c54aef7fa2948192e    9.247645    9.247645
#
#                                                    50%         75%         max
# voter
# 0x008c9f31533dd2a327d0ff28b6fe87194de1e3d3    5.997155    5.997155    5.997155
# 0xa0839d50d601c0ce86677a03739f802fe614ba22   19.997351   19.997351   19.997351
# 0xa009881d1ecddb62a2e15f0ef19c482dd2df1c3a   92.636609   92.636609   92.636609
# 0x9b278aaef429cc4728e594f8fa0fbfe78e72cc26    1.138289    1.138289    1.138289
# 0x921f80499a00ac6e95aae0daa411d338f41d5da2    9.528923    9.528923    9.528923
# ...                                                ...         ...         ...
# 0x40f9bf922c23c43acdad71ab4425280c0ffbd697  200.691627  200.691627  200.691627
# 0x3ffc07ed6a65e379e39bef93e713ee3ff77a56e4   36.972994   36.972994   36.972994
# 0x3e48830bf4415311d13c3c89a0e315ee7398d114    3.792925    3.792925    3.792925
# 0x71f84aa585e1eda8852dad8dff3a69d114366dba    9.734560    9.734560    9.734560
# 0xff56ec56a405716accaa4e6c54aef7fa2948192e    9.247645    9.247645    9.247645
#
# [81 rows x 8 columns]

# %% [markdown]
# This is interesting lets look at which project they gave
#
# Nonetheless some donations are very similar in the amount donated lets try to dig into them

# %%
# inparticular address that donated close to 9.5$
same_amount = gb_donation_usd[np.logical_and(gb_donation_usd['count'] == 1, np.floor(gb_donation_usd['mean']) == 9)].sort_values(by='count', ascending=True)
same_amount
# Out:
#                                             count      mean  std       min
# voter
# 0x2e3e22f9f4d2de3dbdee9cbf350e22afb1c1d6b9    1.0  9.515146  NaN  9.515146  \
# 0x588f6ccb39f3d474c5b3736483589e2bbc8e0847    1.0  9.281587  NaN  9.281587
# 0x70b224998167a500ef39ed91e35ad133d996e744    1.0  9.494141  NaN  9.494141
# 0x71f84aa585e1eda8852dad8dff3a69d114366dba    1.0  9.734560  NaN  9.734560
# 0x7267db34b6072080923f92e626c2fc5da91ff25b    1.0  9.219747  NaN  9.219747
# 0x745339df47cb4186be2fc573e81d50e598b99aef    1.0  9.399484  NaN  9.399484
# 0x921f80499a00ac6e95aae0daa411d338f41d5da2    1.0  9.528923  NaN  9.528923
# 0xa34faa5b9b9e29c191e163a520edeea93a574ba3    1.0  9.497355  NaN  9.497355
# 0xae65dfac43c1dd0b4e4976128d654adf597f756c    1.0  9.556308  NaN  9.556308
# 0xaee2e6432db54a6f3770d57f1108cd326f2b224f    1.0  9.497355  NaN  9.497355
# 0xbb49ccec023dc369844eec3190503853b1380606    1.0  9.497355  NaN  9.497355
# 0xe4c140a67a3a95913a6e2fcfc6d6434d94c07641    1.0  9.436143  NaN  9.436143
# 0xe8fb09228d1373f931007ca7894a08344b80901c    1.0  9.797497  NaN  9.797497
# 0xff56ec56a405716accaa4e6c54aef7fa2948192e    1.0  9.247645  NaN  9.247645
#
#                                                  25%       50%       75%
# voter
# 0x2e3e22f9f4d2de3dbdee9cbf350e22afb1c1d6b9  9.515146  9.515146  9.515146  \
# 0x588f6ccb39f3d474c5b3736483589e2bbc8e0847  9.281587  9.281587  9.281587
# 0x70b224998167a500ef39ed91e35ad133d996e744  9.494141  9.494141  9.494141
# 0x71f84aa585e1eda8852dad8dff3a69d114366dba  9.734560  9.734560  9.734560
# 0x7267db34b6072080923f92e626c2fc5da91ff25b  9.219747  9.219747  9.219747
# 0x745339df47cb4186be2fc573e81d50e598b99aef  9.399484  9.399484  9.399484
# 0x921f80499a00ac6e95aae0daa411d338f41d5da2  9.528923  9.528923  9.528923
# 0xa34faa5b9b9e29c191e163a520edeea93a574ba3  9.497355  9.497355  9.497355
# 0xae65dfac43c1dd0b4e4976128d654adf597f756c  9.556308  9.556308  9.556308
# 0xaee2e6432db54a6f3770d57f1108cd326f2b224f  9.497355  9.497355  9.497355
# 0xbb49ccec023dc369844eec3190503853b1380606  9.497355  9.497355  9.497355
# 0xe4c140a67a3a95913a6e2fcfc6d6434d94c07641  9.436143  9.436143  9.436143
# 0xe8fb09228d1373f931007ca7894a08344b80901c  9.797497  9.797497  9.797497
# 0xff56ec56a405716accaa4e6c54aef7fa2948192e  9.247645  9.247645  9.247645
#
#                                                  max
# voter
# 0x2e3e22f9f4d2de3dbdee9cbf350e22afb1c1d6b9  9.515146
# 0x588f6ccb39f3d474c5b3736483589e2bbc8e0847  9.281587
# 0x70b224998167a500ef39ed91e35ad133d996e744  9.494141
# 0x71f84aa585e1eda8852dad8dff3a69d114366dba  9.734560
# 0x7267db34b6072080923f92e626c2fc5da91ff25b  9.219747
# 0x745339df47cb4186be2fc573e81d50e598b99aef  9.399484
# 0x921f80499a00ac6e95aae0daa411d338f41d5da2  9.528923
# 0xa34faa5b9b9e29c191e163a520edeea93a574ba3  9.497355
# 0xae65dfac43c1dd0b4e4976128d654adf597f756c  9.556308
# 0xaee2e6432db54a6f3770d57f1108cd326f2b224f  9.497355
# 0xbb49ccec023dc369844eec3190503853b1380606  9.497355
# 0xe4c140a67a3a95913a6e2fcfc6d6434d94c07641  9.436143
# 0xe8fb09228d1373f931007ca7894a08344b80901c  9.797497
# 0xff56ec56a405716accaa4e6c54aef7fa2948192e  9.247645

# %%
def get_grant_title(address, df_application, df_votes):
    project_address = df_votes[df_votes['voter'] == address]['grantAddress'].values[0]
    return df_application[df_application['metadata.application.recipient'] == project_address]['metadata.application.project.title'].values[0]

# %%
for address in same_amount.index:
    print(f'Address: {address} Project: {get_grant_title(address, df_application, df_votes)}')
# Out:
# Address: 0x2e3e22f9f4d2de3dbdee9cbf350e22afb1c1d6b9 Project: Unitap
# Address: 0x588f6ccb39f3d474c5b3736483589e2bbc8e0847 Project: Mechanism Institute: Democratizing Cryptoeconomics
# Address: 0x70b224998167a500ef39ed91e35ad133d996e744 Project: BanklessDAO Projects
# Address: 0x71f84aa585e1eda8852dad8dff3a69d114366dba Project: Web3TalentFair
# Address: 0x7267db34b6072080923f92e626c2fc5da91ff25b Project: Unitap
# Address: 0x745339df47cb4186be2fc573e81d50e598b99aef Project: GreenPill Global
# Address: 0x921f80499a00ac6e95aae0daa411d338f41d5da2 Project: JobStash
# Address: 0xa34faa5b9b9e29c191e163a520edeea93a574ba3 Project: BanklessDAO Projects
# Address: 0xae65dfac43c1dd0b4e4976128d654adf597f756c Project: Web3ForGood
# Address: 0xaee2e6432db54a6f3770d57f1108cd326f2b224f Project: BanklessDAO Projects
# Address: 0xbb49ccec023dc369844eec3190503853b1380606 Project: BanklessDAO Projects
# Address: 0xe4c140a67a3a95913a6e2fcfc6d6434d94c07641 Project: ReFi Japan
# Address: 0xe8fb09228d1373f931007ca7894a08344b80901c Project: Unitap
# Address: 0xff56ec56a405716accaa4e6c54aef7fa2948192e Project: H.E.R. DAO

# %% [markdown]
# This analysis is pointing to a suspicion for the project "BanklessDAO Projects" and "Unitap"
#
# However the project "BanklessDAO Projects" is well known.
#
# My guess is that there is a lot of collusion within these addresses and there donation should not be matched. Especially knowing some of these addresses are flagged. Let's verify it.

# %%
df_matching_address[df_matching_address['address'].isin(same_amount.index)]
# Out:
#                                          address  seed_same_naive  seed_same
# 172   0x2e3e22f9f4d2de3dbdee9cbf350e22afb1c1d6b9            False      False  \
# 348   0x588f6ccb39f3d474c5b3736483589e2bbc8e0847            False      False
# 439   0x70b224998167a500ef39ed91e35ad133d996e744            False      False
# 445   0x71f84aa585e1eda8852dad8dff3a69d114366dba            False      False
# 447   0x7267db34b6072080923f92e626c2fc5da91ff25b             True       True
# 455   0x745339df47cb4186be2fc573e81d50e598b99aef             True       True
# 556   0x921f80499a00ac6e95aae0daa411d338f41d5da2            False      False
# 636   0xa34faa5b9b9e29c191e163a520edeea93a574ba3            False      False
# 685   0xae65dfac43c1dd0b4e4976128d654adf597f756c            False      False
# 687   0xaee2e6432db54a6f3770d57f1108cd326f2b224f            False      False
# 749   0xbb49ccec023dc369844eec3190503853b1380606            False      False
# 908   0xe4c140a67a3a95913a6e2fcfc6d6434d94c07641             True       True
# 924   0xe8fb09228d1373f931007ca7894a08344b80901c            False      False
# 1020  0xff56ec56a405716accaa4e6c54aef7fa2948192e            False      False
#
#       seed_suspicious  less_5_tx  less_10_tx  interacted_other_ctbt
# 172             False      False       False                   True  \
# 348             False      False       False                  False
# 439             False      False       False                   True
# 445             False      False       False                  False
# 447             False      False       False                   True
# 455             False      False       False                  False
# 556             False      False       False                   True
# 636             False      False       False                   True
# 685             False      False       False                   True
# 687             False      False       False                   True
# 749             False      False       False                   True
# 908             False      False       False                  False
# 924             False      False       False                   True
# 1020            False      False       False                  False
#
#       count_interaction_with_pool  count_interaction_with_toxic
# 172                             5                             0  \
# 348                            14                             0
# 439                             2                             0
# 445                             8                             0
# 447                             3                             0
# 455                             0                             0
# 556                             3                             0
# 636                             3                             0
# 685                             0                             0
# 687                             2                             0
# 749                             2                             0
# 908                            18                             0
# 924                             5                             0
# 1020                            1                             0
#
#       count_interaction_with_airdrop_m  is_airdrop_master
# 172                                 12               True  \
# 348                                  0              False
# 439                                  4               True
# 445                                  1               True
# 447                                  2              False
# 455                                  1              False
# 556                                  0              False
# 636                                 42              False
# 685                                  5              False
# 687                                 19              False
# 749                                 18              False
# 908                                  2              False
# 924                                 20              False
# 1020                                 4              False
#
#       count_interaction_with_tornado  count_interaction_with_disperse
# 172                                0                                0  \
# 348                                1                                0
# 439                                0                                0
# 445                                0                                0
# 447                                0                                0
# 455                                0                                0
# 556                                1                                0
# 636                                1                                0
# 685                                0                                0
# 687                                0                                0
# 749                                0                                0
# 908                                0                                0
# 924                                0                                0
# 1020                               0                                0
#
#       has_interaction_toxic  has_no_pool_interaction
# 172                   False                     True  \
# 348                   False                    False
# 439                   False                     True
# 445                   False                    False
# 447                   False                     True
# 455                   False                     True
# 556                   False                     True
# 636                   False                     True
# 685                   False                     True
# 687                   False                     True
# 749                   False                     True
# 908                   False                    False
# 924                   False                     True
# 1020                  False                     True
#
#       has_interaction_airdrop_m  has_interaction_tornado
# 172                        True                    False  \
# 348                       False                     True
# 439                        True                    False
# 445                        True                    False
# 447                        True                    False
# 455                        True                    False
# 556                       False                     True
# 636                        True                     True
# 685                        True                    False
# 687                        True                    False
# 749                        True                    False
# 908                        True                    False
# 924                        True                    False
# 1020                       True                    False
#
#       has_interaction_disperse  count_flags  suspicious_1
# 172                      False            4          True
# 348                      False            1         False
# 439                      False            4          True
# 445                      False            2         False
# 447                      False            3          True
# 455                      False            2         False
# 556                      False            3          True
# 636                      False            4          True
# 685                      False            3          True
# 687                      False            3          True
# 749                      False            3          True
# 908                      False            1         False
# 924                      False            3          True
# 1020                     False            2         False

# %%
same_amount_tx = df_tx[np.logical_or(df_tx['from_address'].isin(same_amount.index), df_tx['to_address'].isin(same_amount.index))]
txa_same_amount = txa(same_amount_tx, pd.DataFrame(same_amount.index, columns=['address']))

# %% [markdown]
# All true values mean that the wallet are connected between themselves in that small cluster of addresses

# %%
same_amount.reset_index()['voter'].apply(lambda x : txa_same_amount.has_interacted_with_other_contributor(x)).values
# Out:
# array([ True, False,  True, False,  True, False,  True,  True,  True,
#         True,  True, False,  True, False])

# %%
# explore other suspicious addresses
add_sus = gb_donation_usd[np.logical_and(gb_donation_usd['count'] == 1, gb_donation_usd['mean'] < 25)].index.values
len(add_sus)
# Out:
# 45

# %%
df_1_donation = df_vote_interact_sus[df_vote_interact_sus['voter'].isin(add_sus)]

# %%
print(f'Number of votes {df_1_donation.shape[0]} Number of projects voted: {df_1_donation.grantAddress.nunique()}')
# Merge the project the user voted for and the projects 
gr_sus = df_1_donation['grantAddress'].value_counts().reset_index().merge(df_application, left_on='grantAddress', right_on='metadata.application.recipient', how='left').drop_duplicates(subset='grantAddress').loc[:, ['grantAddress', 'metadata.application.project.title', 'count', 'roundId', 'status']].reset_index(drop=True)
gr_sus.sort_values(by='count', ascending=False)
# Out:
# Number of votes 45 Number of projects voted: 28
#                                   grantAddress
# 0   0x4adc8cc149a03f44386bee80bab36f9e8022b195  \
# 1   0xf26d1bb347a59f6c283c53156519cc1b1abaca51
# 2   0x4cd6b4503d02973d78cff59c9c56f5f378688274
# 3   0xaa163c47065c22d17ed1c47e3e244337d2056c17
# 4   0x8efef51d19ef3844c00076ab9d02847b9c70f94a
# 5   0xdb587c215626cc38c04f9e283e159f3907791baf
# 6   0xd6823f807c45efdc56c9ae8db0226ca10af6e8ab
# 22  0x98714debf8c3114cffbdf04bb49c2e24c899c932
# 19  0x486c853c41885d9c1edb57c423853fc4fbc60769
# 20  0x2ec655969160ab38d308140f3817a0e3be0ca9f2
# 21  0x36f322fc85b24ab13263cfe9217b28f8e2b38381
# 25  0x92ed8f6a9211f9eb0f16c83a052e75099b7bf4a5
# 23  0x3c8ad6f38a060a5b01af26fe1e1ed9c50c32902b
# 24  0xe82a0db3cf329844f22547fe0ef84eca8108e008
# 17  0x743b8e21eb7bd3cb81e521b5f3e7f3c6fbe61d33
# 26  0xf2f099d2d133e2f3d1ed8417ca71e914a3185897
# 18  0x2e8e95dbeb137a24469e711079ad483d081166f7
# 14  0xb79f0156573a54e852fb9ac7b5bc6250b33405a0
# 16  0x300da191248a500b2174aed992d6697bf97f9139
# 15  0x9dcba70b2dfe5807e2a847e065ebb666791f8b8a
# 13  0xc36e4889a820bd8089a8ad226ee9d0c703aed314
# 12  0x5c69b671b91df2d8b0f7f5d962ae39c80388caf9
# 11  0x3d2c7d934d0b0f2979de988e0092aa8c2ccfc638
# 10  0x50b25efa4a8b2eb1986e3bfbdc1f4ade756c806c
# 9   0x2242f42f5ac525d967dfa9f21098160870edd978
# 8   0x4a44a94dfcd91d6a269fef0f167133f3231a7338
# 7   0xaf66321c8cce672c1140bf8c2d3c0dbc07c15c56
# 27  0x32b74b90407309f6637245292cd90347de658a37
#
#                    metadata.application.project.title  count
# 0                                              Unitap      9  \
# 1                                BanklessDAO Projects      4
# 2   Mechanism Institute: Democratizing Cryptoecono...      3
# 3                                            JobStash      2
# 4                                            Pentacle      2
# 5                                              xBound      2
# 6                                       登链社区(Upchain)      2
# 22                                          Open Town      1
# 19                                        Blu3 Global      1
# 20                           KultureCity F THE NEVERS      1
# 21                                    Blocktrend（區塊勢）      1
# 25                                     Web3TalentFair      1
# 23                                         ReFi Japan      1
# 24  VoiceDeck: A Marketplace for Journalism Impact...      1
# 17                                  GreenPill Global       1
# 26                                 Crypto Fundraising      1
# 18                                    Boring Security      1
# 14                                        Web3ForGood      1
# 16                                               DAZE      1
# 15                                        B<>rder/ess      1
# 13                                  Crypto Babes Club      1
# 12                                 ENS DAO Newsletter      1
# 11                                            Revolte      1
# 10                                        H.E.R. DAO       1
# 9                                         Techstation      1
# 8                                          CreatorDAO      1
# 7                                          SEED Latam      1
# 27        Somer Esat Ethereum Staking Guides (Ubuntu)      1
#
#                                        roundId    status
# 0   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 1   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 2   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 3   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 4   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 5   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 6   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 22  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 19  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 20  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 21  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 25  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 23  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 24  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 17  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 26  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 18  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 14  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 16  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 15  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 13  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 12  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 11  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 10  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 9   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 8   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 7   0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED
# 27  0xaa40e2e5c8df03d792a52b5458959c320f86ca18  APPROVED

# %% [markdown]
# By reviewing manually I did not find that any of these projects were suspicious.

# %%
df_matching_address[df_matching_address['has_interaction_toxic']]
# Out:
#                                          address  seed_same_naive  seed_same
# 36    0x0a251df99a88a20a93876205fb7f5faf2e85a481            False      False  \
# 45    0x0bb602f88bf886282ff69d4cec937cc2a7d9e19a             True       True
# 158   0x293c173b0ae90cd27c349cd8892efa625a98dbae            False      False
# 308   0x504c11bdbe6e29b46e23e9a15d9c8d2e2e795709            False      False
# 356   0x5a930b098ed8d58dd4590577af85a8e864a8f6fe             True       True
# 427   0x6d526f6b4c86fbdc8e359e6bef4cd6a42acea2d7             True       True
# 460   0x767a60f295aedd958932088f9cd6a4951d8739b6            False      False
# 481   0x7bc1d6e8150d4c96917901c26c922dd64654b3c3             True       True
# 510   0x85274906f537e0aa3823855bd6a0e374c771d19b            False      False
# 563   0x93907de38066d70109935732757b625d636e47b6             True       True
# 585   0x984b18b1823fef04a4ca7cf1e8a0ef5359fa522f            False      False
# 596   0x9aa470470cac9ab75e2b8648c9c054560749b33d            False      False
# 597   0x9b278aaef429cc4728e594f8fa0fbfe78e72cc26             True       True
# 642   0xa4ca1b15fe81f57cb2d3f686c7b13309906cd37b             True       True
# 684   0xae5679c84371d53c7e2bb2870f9d00e92d506e0c             True       True
# 821   0xcf61ebd3613684a53e48ee85d8fbc80c5156c479             True       True
# 898   0xe04885c3f1419c6e8495c33bdcf5f8387cd88846             True       True
# 1002  0xfb40932271fc9db9dbf048e80697e2da4aa57250            False      False
#
#       seed_suspicious  less_5_tx  less_10_tx  interacted_other_ctbt
# 36              False      False       False                  False  \
# 45              False      False       False                  False
# 158             False      False       False                   True
# 308             False      False       False                  False
# 356             False      False       False                   True
# 427             False      False       False                  False
# 460             False      False       False                  False
# 481             False      False       False                  False
# 510             False      False       False                   True
# 563             False      False       False                   True
# 585             False      False       False                  False
# 596             False      False       False                  False
# 597             False      False       False                  False
# 642             False      False       False                  False
# 684             False      False       False                  False
# 821             False      False       False                  False
# 898             False      False       False                  False
# 1002            False      False       False                   True
#
#       count_interaction_with_pool  count_interaction_with_toxic
# 36                            106                             1  \
# 45                             15                             5
# 158                             0                             1
# 308                            34                             1
# 356                             0                             1
# 427                             6                             1
# 460                            78                             1
# 481                            64                             1
# 510                             4                             1
# 563                            16                             1
# 585                             4                             2
# 596                            14                             1
# 597                             0                             1
# 642                            82                             3
# 684                             8                             1
# 821                             7                             2
# 898                            33                             1
# 1002                           76                             1
#
#       count_interaction_with_airdrop_m  is_airdrop_master
# 36                                  10               True  \
# 45                                   0              False
# 158                                  3              False
# 308                                 11              False
# 356                                  0              False
# 427                                  3               True
# 460                                  8               True
# 481                                  0              False
# 510                                  3              False
# 563                                  0              False
# 585                                 10              False
# 596                                  4              False
# 597                                  0              False
# 642                                  4              False
# 684                                  2              False
# 821                                  0              False
# 898                                  7               True
# 1002                                68               True
#
#       count_interaction_with_tornado  count_interaction_with_disperse
# 36                                 1                                0  \
# 45                                 0                                0
# 158                                0                                0
# 308                                4                                2
# 356                                0                                0
# 427                                0                                0
# 460                                0                                0
# 481                                0                                0
# 510                                0                                0
# 563                                0                                0
# 585                                0                                0
# 596                                0                                0
# 597                                0                                0
# 642                                0                                0
# 684                                0                                0
# 821                                0                                0
# 898                                0                                0
# 1002                               0                                1
#
#       has_interaction_toxic  has_no_pool_interaction
# 36                     True                    False  \
# 45                     True                    False
# 158                    True                     True
# 308                    True                    False
# 356                    True                     True
# 427                    True                    False
# 460                    True                    False
# 481                    True                    False
# 510                    True                     True
# 563                    True                    False
# 585                    True                     True
# 596                    True                    False
# 597                    True                     True
# 642                    True                    False
# 684                    True                    False
# 821                    True                    False
# 898                    True                    False
# 1002                   True                    False
#
#       has_interaction_airdrop_m  has_interaction_tornado
# 36                         True                     True  \
# 45                        False                    False
# 158                        True                    False
# 308                        True                     True
# 356                       False                    False
# 427                        True                    False
# 460                        True                    False
# 481                       False                    False
# 510                        True                    False
# 563                       False                    False
# 585                        True                    False
# 596                        True                    False
# 597                       False                    False
# 642                        True                    False
# 684                        True                    False
# 821                       False                    False
# 898                        True                    False
# 1002                       True                    False
#
#       has_interaction_disperse  count_flags  suspicious_1
# 36                       False            4          True
# 45                       False            1         False
# 158                      False            4          True
# 308                       True            4          True
# 356                      False            3          True
# 427                      False            3          True
# 460                      False            3          True
# 481                      False            1         False
# 510                      False            4          True
# 563                      False            2         False
# 585                      False            3          True
# 596                      False            2         False
# 597                      False            2         False
# 642                      False            2         False
# 684                      False            2         False
# 821                      False            1         False
# 898                      False            3          True
# 1002                      True            5          True

# %%
df_matching_address[np.logical_and(np.logical_and(df_matching_address['has_interaction_airdrop_m'], df_matching_address['is_airdrop_master']), df_matching_address['has_interaction_disperse'])]
# Out:
#                                          address  seed_same_naive  seed_same
# 319   0x52432473144056fe91aeae9240ad21e6b8213440            False      False  \
# 503   0x839395e20bbb182fa440d08f850e6c7a8f6f0780            False      False
# 561   0x9325564ade7683706107685cf1993678b1163261            False      False
# 696   0xb08f95dbc639621dbaf48a472ae8fce0f6f56a6e             True       True
# 857   0xd6f5646d9e7fbee7cc907eb8e12dafa5378431e6            False      False
# 1002  0xfb40932271fc9db9dbf048e80697e2da4aa57250            False      False
#
#       seed_suspicious  less_5_tx  less_10_tx  interacted_other_ctbt
# 319             False      False       False                   True  \
# 503             False      False       False                   True
# 561             False      False       False                  False
# 696             False      False       False                   True
# 857             False      False       False                   True
# 1002            False      False       False                   True
#
#       count_interaction_with_pool  count_interaction_with_toxic
# 319                             3                             0  \
# 503                           245                             0
# 561                            59                             0
# 696                            56                             0
# 857                            14                             0
# 1002                           76                             1
#
#       count_interaction_with_airdrop_m  is_airdrop_master
# 319                                  4               True  \
# 503                                 96               True
# 561                                 10               True
# 696                                 40               True
# 857                                 40               True
# 1002                                68               True
#
#       count_interaction_with_tornado  count_interaction_with_disperse
# 319                                0                                1  \
# 503                                8                                1
# 561                               18                               16
# 696                                0                                3
# 857                                1                                1
# 1002                               0                                1
#
#       has_interaction_toxic  has_no_pool_interaction
# 319                   False                     True  \
# 503                   False                    False
# 561                   False                    False
# 696                   False                    False
# 857                   False                    False
# 1002                   True                    False
#
#       has_interaction_airdrop_m  has_interaction_tornado
# 319                        True                    False  \
# 503                        True                     True
# 561                        True                     True
# 696                        True                    False
# 857                        True                     True
# 1002                       True                    False
#
#       has_interaction_disperse  count_flags  suspicious_1
# 319                       True            5          True
# 503                       True            5          True
# 561                       True            4          True
# 696                       True            4          True
# 857                       True            5          True
# 1002                      True            5          True

# %% [markdown]
# Amost every airdrop master has interacted with another aidrop master. This is very suspicious. It means they are very connected to each other. These addresses are probably controlled by the same person or a group of person and thus their donation should not be matched.

# %%
df_suspicious_1.sort_values(by='count_flags', ascending=False).head(20)
# Out:
#                                          address  seed_same_naive  seed_same
# 319   0x52432473144056fe91aeae9240ad21e6b8213440            False      False  \
# 503   0x839395e20bbb182fa440d08f850e6c7a8f6f0780            False      False
# 416   0x693edbcf118ec982f5a8101498b6c789470b0b89            False      False
# 449   0x7307174ed422e37cb5254b944ffa762907f0b41b            False      False
# 453   0x74160cb9d7900c65e9f716bf3fde36c0ec335a78             True       True
# 857   0xd6f5646d9e7fbee7cc907eb8e12dafa5378431e6            False      False
# 1002  0xfb40932271fc9db9dbf048e80697e2da4aa57250            False      False
# 561   0x9325564ade7683706107685cf1993678b1163261            False      False
# 702   0xb1b7586656116d546033e3baff69bfcd6592225e             True       True
# 158   0x293c173b0ae90cd27c349cd8892efa625a98dbae            False      False
# 172   0x2e3e22f9f4d2de3dbdee9cbf350e22afb1c1d6b9            False      False
# 173   0x2e586806e193d22bbfbe9c466a35456c7bf73b5b             True       True
# 830   0xd11b4b2a4b9b31bf4e8f879e2036ddccab6fcb6f            False      False
# 811   0xccc6848c9f8d31ff6bf3136e5845b3f57f59b47a             True       True
# 194   0x32cefb2dc869bbfe636f7547cda43f561bf88d5a            False      False
# 797   0xc94caa5b4c1136fb1facd5dea83f25ec6a6cbd65            False      False
# 523   0x89343fbf39e484bbf502a9b564b3c9dfeb1b6e59             True       True
# 763   0xbe0284a4a260df4c58eec491d41995ceee3fac58             True       True
# 270   0x46ce1348b3dd340a9323aa21ed6c3a90359882ca             True       True
# 713   0xb310d025e6054233b1f4b083bd9228197e7fd2d8            False      False
#
#       seed_suspicious  less_5_tx  less_10_tx  interacted_other_ctbt
# 319             False      False       False                   True  \
# 503             False      False       False                   True
# 416             False      False       False                   True
# 449             False       True        True                   True
# 453             False       True        True                   True
# 857             False      False       False                   True
# 1002            False      False       False                   True
# 561             False      False       False                  False
# 702             False      False       False                   True
# 158             False      False       False                   True
# 172             False      False       False                   True
# 173             False       True        True                   True
# 830             False      False        True                   True
# 811             False       True        True                   True
# 194             False      False       False                   True
# 797             False       True        True                   True
# 523             False       True        True                   True
# 763             False      False       False                  False
# 270             False       True        True                   True
# 713             False       True        True                   True
#
#       count_interaction_with_pool  count_interaction_with_toxic
# 319                             3                             0  \
# 503                           245                             0
# 416                             1                             0
# 449                             0                             0
# 453                             0                             0
# 857                            14                             0
# 1002                           76                             1
# 561                            59                             0
# 702                            13                             0
# 158                             0                             1
# 172                             5                             0
# 173                             0                             0
# 830                             0                             0
# 811                             0                             0
# 194                             3                             0
# 797                             0                             0
# 523                             0                             0
# 763                             5                             0
# 270                             0                             0
# 713                             0                             0
#
#       count_interaction_with_airdrop_m  is_airdrop_master
# 319                                  4               True  \
# 503                                 96               True
# 416                                  3               True
# 449                                  1              False
# 453                                  1              False
# 857                                 40               True
# 1002                                68               True
# 561                                 10               True
# 702                                 86               True
# 158                                  3              False
# 172                                 12               True
# 173                                  0              False
# 830                                  1              False
# 811                                  0              False
# 194                                  5               True
# 797                                  0              False
# 523                                  0              False
# 763                                  4               True
# 270                                  0              False
# 713                                  0              False
#
#       count_interaction_with_tornado  count_interaction_with_disperse
# 319                                0                                1  \
# 503                                8                                1
# 416                                2                                0
# 449                                0                                0
# 453                                0                                0
# 857                                1                                1
# 1002                               0                                1
# 561                               18                               16
# 702                                3                                0
# 158                                0                                0
# 172                                0                                0
# 173                                0                                0
# 830                                0                                0
# 811                                0                                0
# 194                                0                                0
# 797                                0                                0
# 523                                0                                0
# 763                                2                                0
# 270                                0                                0
# 713                                0                                0
#
#       has_interaction_toxic  has_no_pool_interaction
# 319                   False                     True  \
# 503                   False                    False
# 416                   False                     True
# 449                   False                     True
# 453                   False                     True
# 857                   False                    False
# 1002                   True                    False
# 561                   False                    False
# 702                   False                    False
# 158                    True                     True
# 172                   False                     True
# 173                   False                     True
# 830                   False                     True
# 811                   False                     True
# 194                   False                     True
# 797                   False                     True
# 523                   False                     True
# 763                   False                     True
# 270                   False                     True
# 713                   False                     True
#
#       has_interaction_airdrop_m  has_interaction_tornado
# 319                        True                    False  \
# 503                        True                     True
# 416                        True                     True
# 449                        True                    False
# 453                        True                    False
# 857                        True                     True
# 1002                       True                    False
# 561                        True                     True
# 702                        True                     True
# 158                        True                    False
# 172                        True                    False
# 173                       False                    False
# 830                        True                    False
# 811                       False                    False
# 194                        True                    False
# 797                       False                    False
# 523                       False                    False
# 763                        True                     True
# 270                       False                    False
# 713                       False                    False
#
#       has_interaction_disperse  count_flags  suspicious_1
# 319                       True            5          True
# 503                       True            5          True
# 416                      False            5          True
# 449                      False            5          True
# 453                      False            5          True
# 857                       True            5          True
# 1002                      True            5          True
# 561                       True            4          True
# 702                      False            4          True
# 158                      False            4          True
# 172                      False            4          True
# 173                      False            4          True
# 830                      False            4          True
# 811                      False            4          True
# 194                      False            4          True
# 797                      False            4          True
# 523                      False            4          True
# 763                      False            4          True
# 270                      False            4          True
# 713                      False            4          True

# %%
flag_bool =['has_interaction_toxic',
 'has_interaction_airdrop_m',
 'has_interaction_tornado',
 'has_interaction_disperse',
 'is_airdrop_master',
 'less_5_tx']

# %%
df_matching_address['flagged'] = df_matching_address[flag_bool].sum(axis=1) > 0
print(f'Number of flagged addresses: {df_matching_address["flagged"].sum()} out of {df_matching_address.shape[0]}')
# Out:
# Number of flagged addresses: 433 out of 1022

# %%
df_matching_address.to_csv('../suspicious_addresses.csv', index=False)

# %% [markdown]
# Almost half of the addresses are flagged

# %% [markdown]
# # Conclusion
#
# We have found a few suspicious projects and addresses.
#
# The proposed stamps for gitcoin passport is passed by 10% of the wallets only. This means it may be a good indicator of human behavior. However it is not enough to flag a wallet as suspicious if it does not have transaction with a decentralized exchange.
#
# The labels retrieved from Flipside Crypto are very useful and points to suspicious addresses that are colluding. They interact between themselves and with other suspicious addresses. This is a very good indicator of sybil behavior. And in particular the flag airdrop master. This addresses could be squelched.
#
# Some labels such as tornado cash is less usefull.
#
# In the contribuotrs 20% had less than 5 transactions that is a lot of wallets.
