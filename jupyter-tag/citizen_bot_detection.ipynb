# %% [markdown]
# Compute a flag based on seed clustereing

# %%
import os
from pathlib import Path
import numpy as np
import requests
import pandas as pd
import joblib

from sbdata.FlipsideApi import FlipsideApi

# %%
# Set path to data folder
current_dir = Path(os.getcwd())
DATA_DIR = os.path.join(current_dir.parent.parent, 'data-regen-rangers')
DATA_DIR_GITCOIN = os.path.join(current_dir.parent.parent, 'data-gitcoin')
GRANT_ROUND_ID = '0x984e29dCB4286c2D9cbAA2c238AfDd8A191Eefbc'
ODC_DATA_DIR = os.path.join(current_dir.parent.parent.parent, 'data')

PATH_TO_VOTES = os.path.join(DATA_DIR_GITCOIN, 'citizen-votes.csv')

# %%
df_matching_address = pd.read_csv(f'../output_gitcoin/full_features/voters_features_{GRANT_ROUND_ID}.csv')
df_votes_feature = pd.read_csv(f'../output_gitcoin/full_features/votes_features_citizen_{GRANT_ROUND_ID}.csv')
df_votes = pd.read_csv(PATH_TO_VOTES).drop(columns=['__row_index'])

# %%
df_matching_address.columns
# Out:
# Index(['seed_same_naive', 'seed_same', 'seed_suspicious', 'less_5_tx',
#        'less_10_tx', 'interacted_other_ctbt', 'lcs', 'cluster_size_lcs',
#        'mean_score_lcs', 'max_score_lcs', 'has_lcs',
#        'count_interaction_with_pool', 'count_interaction_with_toxic',
#        'interact_less_5tx', 'has_interaction_toxic', 'has_no_pool_interaction',
#        'count_interaction_with_airdrop_m', 'is_airdrop_master',
#        'count_interaction_with_tornado', 'count_interaction_with_disperse',
#        'has_interaction_airdrop_m', 'has_interaction_tornado',
#        'has_interaction_disperse', 'flagged', 'stakeridoo_detected',
#        'doge_detected', 'really_suspicicious_cluster', 'odc_detected',
#        'trusta', 'stakeridoo_detected.1', 'doge_detected.1',
#        'really_suspicicious_cluster.1', 'odc_detected.1', 'address'],
#       dtype='object')

# %%
df_votes.columns
# Out:
# Index(['block_timestamp', 'tx_hash', 'voter', 'project', 'amount_usd'], dtype='object')

# %%
print(df_matching_address.shape)
print(df_votes_feature.shape)
# Out:
# (17023, 34)
# (57366, 33)

# %% [markdown]
# Get all the voter addresses

# %%
a_voter_addresses = df_votes['voter'].unique()

# %%
# 3000 random addresses to prevent heavy querying, it is not randomm for reproducibility
small_a_voter_addresses = a_voter_addresses[3000:6000]

# %%
sql_template = """
WITH
  transactions AS (
    SELECT
      BLOCK_TIMESTAMP,
      TX_FEE,
      FROM_ADDRESS AS EOA,
      TO_ADDRESS AS COUNTERPARTY,
      ETH_VALUE,
      1 as BOOLEAN_OUT
    FROM
      optimism.core.fact_transactions
    WHERE
      FROM_ADDRESS IN (%s)
    UNION ALL
    SELECT
      BLOCK_TIMESTAMP,
      TX_FEE,
      TO_ADDRESS AS EOA,
      TO_ADDRESS AS COUNTERPARTY,
      ETH_VALUE,
      0 as BOOLEAN_OUT
    FROM
      optimism.core.fact_transactions
    WHERE
      TO_ADDRESS IN (%s)
  )
SELECT
  EOA,
  COUNT(*) as n_tx,
  COUNT(DISTINCT(COUNTERPARTY)) as n_counterparty,
  SUM(ETH_VALUE) as eth_volume,
  SUM(BOOLEAN_OUT) as n_tx_out,
  n_tx - n_tx_out as n_tx_in,
  n_tx_out - n_tx_in as n_tx_diff_out_in,
  TIMESTAMPDIFF(MINUTE, MIN(BLOCK_TIMESTAMP), CURRENT_TIMESTAMP()) as age,
  TIMESTAMPDIFF(MINUTE, MIN(BLOCK_TIMESTAMP), MAX(BLOCK_TIMESTAMP)) as time_alive,
  CASE WHEN age = 0 THEN 0 ELSE n_tx / age END as tx_min,
  CASE WHEN time_alive = 0 THEN 0 ELSE n_tx / time_alive END as tx_min_alive,
  AVG(TX_FEE) as avg_tx_fee,
  STDDEV(TX_FEE) as std_tx_fee
FROM
  transactions
GROUP BY
  EOA
HAVING
  n_tx < 100;
"""

# %%
# set up api key for flipside
api_key = os.environ['FLIPSIDE_API_KEY2']
flipside_api = FlipsideApi(api_key, timeout_minutes=60, max_address=2000)

# %%
a_voter_addresses.shape
# Out:
# (17023,)

# %%
df_features_add = flipside_api.extract_data_flipside(a_voter_addresses, sql_template)
# Out:
# Extracting for address: 0 - 2000
# Extracting for address: 2000 - 4000
# Extracting for address: 4000 - 6000
# Extracting for address: 6000 - 8000
# Extracting for address: 8000 - 10000
# Extracting for address: 10000 - 12000
# Extracting for address: 12000 - 14000
# Extracting for address: 14000 - 16000
# Extracting for address: 16000 - 18000

# %%
df_features_add['ratio_tx_counterparties'] = df_features_add['n_tx'] / df_features_add['n_counterparty']
df_features_add.drop('__row_index', axis=1, inplace=True)
df_features_add.set_index('eoa', inplace=True)
df_features_add.head(2)
# Out:
#                                             n_tx  n_counterparty  eth_volume
# eoa
# 0xb06c8846ba233938605af625d7ce31190ab604bc    86              48    0.338475  \
# 0x4aa023ca41346cc2869ed4db7588fc58055074e9    72              37    0.439118
#
#                                             n_tx_out  n_tx_in
# eoa
# 0xb06c8846ba233938605af625d7ce31190ab604bc        83        3  \
# 0x4aa023ca41346cc2869ed4db7588fc58055074e9        69        3
#
#                                             n_tx_diff_out_in     age
# eoa
# 0xb06c8846ba233938605af625d7ce31190ab604bc                80  278958  \
# 0x4aa023ca41346cc2869ed4db7588fc58055074e9                66  289407
#
#                                             time_alive    tx_min
# eoa
# 0xb06c8846ba233938605af625d7ce31190ab604bc      264100  0.000308  \
# 0x4aa023ca41346cc2869ed4db7588fc58055074e9      276076  0.000249
#
#                                             tx_min_alive  avg_tx_fee
# eoa
# 0xb06c8846ba233938605af625d7ce31190ab604bc      0.000326    0.000153  \
# 0x4aa023ca41346cc2869ed4db7588fc58055074e9      0.000261    0.000200
#
#                                             std_tx_fee
# eoa
# 0xb06c8846ba233938605af625d7ce31190ab604bc    0.000144  \
# 0x4aa023ca41346cc2869ed4db7588fc58055074e9    0.000233
#
#                                             ratio_tx_counterparties
# eoa
# 0xb06c8846ba233938605af625d7ce31190ab604bc                 1.791667
# 0x4aa023ca41346cc2869ed4db7588fc58055074e9                 1.945946

# %%
df_features_add.isna().sum()
# Out:
# n_tx                        0
# n_counterparty              0
# eth_volume                  0
# n_tx_out                    0
# n_tx_in                     0
# n_tx_diff_out_in            0
# age                         0
# time_alive                  0
# tx_min                      0
# tx_min_alive                0
# avg_tx_fee                  0
# std_tx_fee                 99
# ratio_tx_counterparties     0
# dtype: int64

# %%
df_features_add.std_tx_fee.fillna(0, inplace=True)

# %%
model = joblib.load('optimism_cex_dex_logistic_best.joblib')
prediction = model.predict(df_features_add)

# %%
print(df_features_add.shape)
prediction.size
# Out:
# (9333, 14)
# 9199

# %%
df_features_add['prediction'] = prediction

# %%
df_features_add['prediction'].value_counts()
# Out:
# prediction
# 0.0    9065
# 1.0     134
# Name: count, dtype: int64

# %% [markdown]
# This does not sum to 100% for some unknown reason, we will explore below which addresses are missing.

# %%
df_features_add[df_features_add['prediction']==1].sort_values(by='n_tx', ascending=False).head(10)
# Out:
#                                             n_tx  n_counterparty  eth_volume
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541    40              17    0.228527  \
# 0x164cd0c8124159ebffc74951484616699f74039d    34              16    0.101946
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26    23              15   15.953949
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9    18              18    0.001600
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7    17              10    0.791224
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41    15               7    0.033928
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c    15              10    0.000982
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de    11              11    0.022030
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d     8               7    0.013798
# 0x70469299a97e0957924484273acadae6027c673c     7               6    0.011180
#
#                                             n_tx_out  n_tx_in
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541        37        3  \
# 0x164cd0c8124159ebffc74951484616699f74039d        32        2
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26        19        4
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9        18        0
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7        17        0
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41        15        0
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c        15        0
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de        10        1
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d         7        1
# 0x70469299a97e0957924484273acadae6027c673c         5        2
#
#                                             n_tx_diff_out_in    age
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541                34  61877  \
# 0x164cd0c8124159ebffc74951484616699f74039d                30  49202
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26                15  22822
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9                18  25656
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7                17  33353
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41                15  35152
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c                15  25646
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de                 9  69478
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d                 6  92277
# 0x70469299a97e0957924484273acadae6027c673c                 3  24297
#
#                                             time_alive    tx_min
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541       58788  0.000646  \
# 0x164cd0c8124159ebffc74951484616699f74039d       48760  0.000691
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26          31  0.001008
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9           9  0.000702
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7          36  0.000510
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41          17  0.000427
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c          15  0.000585
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de       65246  0.000158
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d       63346  0.000087
# 0x70469299a97e0957924484273acadae6027c673c          27  0.000288
#
#                                             tx_min_alive  avg_tx_fee
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541      0.000680    0.003297  \
# 0x164cd0c8124159ebffc74951484616699f74039d      0.000697    0.000946
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26      0.741935    0.000063
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9      2.000000    0.000040
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7      0.472222    0.000061
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41      0.882353    0.000062
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c      1.000000    0.000045
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de      0.000169    0.000888
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d      0.000126    0.000743
# 0x70469299a97e0957924484273acadae6027c673c      0.259259    0.000040
#
#                                             std_tx_fee
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541    0.007117  \
# 0x164cd0c8124159ebffc74951484616699f74039d    0.002819
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26    0.000050
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9    0.000028
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7    0.000029
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41    0.000037
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c    0.000022
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de    0.002498
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d    0.000647
# 0x70469299a97e0957924484273acadae6027c673c    0.000027
#
#                                             ratio_tx_counterparties
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541                 2.352941  \
# 0x164cd0c8124159ebffc74951484616699f74039d                 2.125000
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26                 1.533333
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9                 1.000000
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7                 1.700000
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41                 2.142857
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c                 1.500000
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de                 1.000000
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d                 1.142857
# 0x70469299a97e0957924484273acadae6027c673c                 1.166667
#
#                                             prediction
# eoa
# 0x9fc64deb8ba637656b47557acb3e9ed742160541         1.0
# 0x164cd0c8124159ebffc74951484616699f74039d         1.0
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26         1.0
# 0x4c5b9a96b1b522cf5beed817e76426c2912d06b9         1.0
# 0x230acfeb57ad3fd38a43437e841c8305fe2c23e7         1.0
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41         1.0
# 0x4309b0c83036fb2e169ccc8fe2c5a51b7585493c         1.0
# 0xcfc25811af4d9073214b5f652fc6530c4adb93de         1.0
# 0x94879afb25ea02f7c3736f153b4ce27e5765a05d         1.0
# 0x70469299a97e0957924484273acadae6027c673c         1.0

# %% [markdown]
# Lets manually check the first 10 addresses

# %% [markdown]
# These wallets look a lot like airdrop farmer wallets. The time alive for some of these wallets is very short indicating a automatic behavior / bot

# %% [markdown]
# This legos may be more reliable than others such as aidrop master but we can't be sure of the accuracy of this method.

# %% [markdown]
# ## Exploring the missing addresses

# %%
arr_diff = np.setdiff1d(df_features_add.index, df_matching_address.index.unique())
print(len(arr_diff))
# Out:
# 9199

# %%
# Lets try to export the data again for these addresses
df_feature_miss = flipside_api.extract_data_flipside(arr_diff, sql_template)
# Out:
# Extracting for address: 0 - 2000
# Extracting for address: 2000 - 4000
# Extracting for address: 4000 - 6000
# Extracting for address: 6000 - 8000
# Extracting for address: 8000 - 10000

# %%
df_feature_miss.shape
# Out:
# (134, 14)

# %%
df_feature_miss
# Out:
#                                             eoa  n_tx  n_counterparty
# 0    0x94879afb25ea02f7c3736f153b4ce27e5765a05d     8               7  \
# 1    0xbfec3946ff5bc73843f48b3be4b14c7fd36f2422     2               2
# 2    0x181337a1c5268a36bb3001e77afd44c2c69786c6     2               2
# 3    0xf41b98a4c32bb61468c8001e0c69ef64ce6dea57     3               3
# 4    0xc457905e836fddd29a731964942271689c1456ed     3               3
# ..                                          ...   ...             ...
# 129  0x425d84e63e623d0ad74d324710e5d0c53656ca7a     3               2
# 130  0x5b5d6d40da8eb176e8329e328463aac06a5309a2     2               2
# 131  0x2717ae2060084918a338b3a0b3a216cedd810aca     2               2
# 132  0x8073639b11994c549eda58fc3cd7132a72aadf10     1               1
# 133  0x921a05b893021fbdf231e75c02847c70e256917d     3               3
#
#      eth_volume  n_tx_out  n_tx_in  n_tx_diff_out_in    age  time_alive
# 0      0.013798         7        1                 6  92266       63346  \
# 1      0.002175         1        1                 0  41237           2
# 2      0.012490         1        1                 0  42582           1
# 3      0.001000         2        1                 1  22715           8
# 4      0.000537         3        0                 3  23115           1
# ..          ...       ...      ...               ...    ...         ...
# 129    0.049011         2        1                 1  24360           7
# 130    0.001384         1        1                 0  26192           1
# 131    0.003071         1        1                 0  35297           2
# 132    0.073000         1        0                 1  43223           0
# 133    0.014990         2        1                 1  99369       76288
#
#        tx_min  tx_min_alive  avg_tx_fee  std_tx_fee  __row_index
# 0    0.000087      0.000126    0.000743    0.000647            0
# 1    0.000049      1.000000    0.000046    0.000025            1
# 2    0.000047      2.000000    0.000076    0.000030            2
# 3    0.000132      0.375000    0.000047    0.000031            3
# 4    0.000130      3.000000    0.000191    0.000082            4
# ..        ...           ...         ...         ...          ...
# 129  0.000123      0.428571    0.000078    0.000020          129
# 130  0.000076      2.000000    0.000038    0.000019          130
# 131  0.000057      1.000000    0.000052    0.000040          131
# 132  0.000023      0.000000    0.000808         NaN          132
# 133  0.000030      0.000039    0.001335    0.001373          133
#
# [134 rows x 14 columns]

# %% [markdown]
# This may because of the flipside api with too many rows in memmory at some point in time. We should use max_address = 3000

# %%
df_feature_miss['ratio_tx_counterparties'] = df_feature_miss['n_tx'] / df_feature_miss['n_counterparty']
df_feature_miss.drop('__row_index', axis=1, inplace=True)
df_feature_miss.set_index('eoa', inplace=True)

# %%
df_features_add = pd.concat([df_features_add, df_feature_miss])
df_features_add['prediction'].value_counts()
# Out:
# prediction
# 0.0    9065
# 1.0     134
# Name: count, dtype: int64

# %%
df_features_add.tail(20)
# Out:
#                                             n_tx  n_counterparty  eth_volume
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5     3               3    0.000530  \
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5     2               2    0.006050
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b     3               3    0.001940
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b     2               2    0.007459
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4     5               3    0.007567
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8     2               2    0.018767
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681     4               4    0.002796
# 0x712b4018ce224dca5ca9100f63c14893f977167d     2               2    0.004064
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b     2               2    0.067367
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26    23              15   15.953949
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52     2               1    0.020000
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee     3               3    0.035965
# 0x76cfcac55192b381cd7b973acd12a58315072032     2               2    0.003000
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c     2               2    0.028000
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41    15               7    0.033928
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a     3               2    0.049011
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2     2               2    0.001384
# 0x2717ae2060084918a338b3a0b3a216cedd810aca     2               2    0.003071
# 0x8073639b11994c549eda58fc3cd7132a72aadf10     1               1    0.073000
# 0x921a05b893021fbdf231e75c02847c70e256917d     3               3    0.014990
#
#                                             n_tx_out  n_tx_in
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5         3        0  \
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5         1        1
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b         3        0
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b         1        1
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4         4        1
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8         1        1
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681         3        1
# 0x712b4018ce224dca5ca9100f63c14893f977167d         1        1
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b         1        1
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26        19        4
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52         2        0
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee         2        1
# 0x76cfcac55192b381cd7b973acd12a58315072032         1        1
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c         1        1
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41        15        0
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a         2        1
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2         1        1
# 0x2717ae2060084918a338b3a0b3a216cedd810aca         1        1
# 0x8073639b11994c549eda58fc3cd7132a72aadf10         1        0
# 0x921a05b893021fbdf231e75c02847c70e256917d         2        1
#
#                                             n_tx_diff_out_in    age
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5                 3  23000  \
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5                 0  24460
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b                 3  23183
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b                 0  24749
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4                 3  25833
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8                 0  30700
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681                 2  25737
# 0x712b4018ce224dca5ca9100f63c14893f977167d                 0  25130
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b                 0  24813
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26                15  22812
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52                 2  24630
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee                 1  24549
# 0x76cfcac55192b381cd7b973acd12a58315072032                 0  39582
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c                 0  30218
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41                15  35139
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a                 1  24360
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2                 0  26192
# 0x2717ae2060084918a338b3a0b3a216cedd810aca                 0  35297
# 0x8073639b11994c549eda58fc3cd7132a72aadf10                 1  43223
# 0x921a05b893021fbdf231e75c02847c70e256917d                 1  99369
#
#                                             time_alive    tx_min
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5           1  0.000130  \
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5           6  0.000082
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b          10  0.000129
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b           7  0.000081
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4          12  0.000194
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8           6  0.000065
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681           9  0.000155
# 0x712b4018ce224dca5ca9100f63c14893f977167d           2  0.000080
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b           3  0.000081
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26          31  0.001008
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52           2  0.000081
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee           3  0.000122
# 0x76cfcac55192b381cd7b973acd12a58315072032           7  0.000051
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c           6  0.000066
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41          17  0.000427
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a           7  0.000123
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2           1  0.000076
# 0x2717ae2060084918a338b3a0b3a216cedd810aca           2  0.000057
# 0x8073639b11994c549eda58fc3cd7132a72aadf10           0  0.000023
# 0x921a05b893021fbdf231e75c02847c70e256917d       76288  0.000030
#
#                                             tx_min_alive  avg_tx_fee
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5      3.000000    0.000067  \
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5      0.333333    0.000102
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b      0.300000    0.000111
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b      0.285714    0.000068
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4      0.416667    0.000042
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8      0.333333    0.000100
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681      0.444444    0.000060
# 0x712b4018ce224dca5ca9100f63c14893f977167d      1.000000    0.000062
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b      0.666667    0.000202
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26      0.741935    0.000063
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52      1.000000    0.000159
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee      1.000000    0.000039
# 0x76cfcac55192b381cd7b973acd12a58315072032      0.285714    0.000047
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c      0.333333    0.000190
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41      0.882353    0.000062
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a      0.428571    0.000078
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2      2.000000    0.000038
# 0x2717ae2060084918a338b3a0b3a216cedd810aca      1.000000    0.000052
# 0x8073639b11994c549eda58fc3cd7132a72aadf10      0.000000    0.000808
# 0x921a05b893021fbdf231e75c02847c70e256917d      0.000039    0.001335
#
#                                             std_tx_fee
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5    0.000027  \
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5    0.000097
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b    0.000119
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b    0.000058
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4    0.000011
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8    0.000044
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681    0.000017
# 0x712b4018ce224dca5ca9100f63c14893f977167d    0.000004
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b    0.000188
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26    0.000050
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52    0.000007
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee    0.000015
# 0x76cfcac55192b381cd7b973acd12a58315072032    0.000022
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c    0.000229
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41    0.000037
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a    0.000020
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2    0.000019
# 0x2717ae2060084918a338b3a0b3a216cedd810aca    0.000040
# 0x8073639b11994c549eda58fc3cd7132a72aadf10         NaN
# 0x921a05b893021fbdf231e75c02847c70e256917d    0.001373
#
#                                             ratio_tx_counterparties
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5                 1.000000  \
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5                 1.000000
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b                 1.000000
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b                 1.000000
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4                 1.666667
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8                 1.000000
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681                 1.000000
# 0x712b4018ce224dca5ca9100f63c14893f977167d                 1.000000
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b                 1.000000
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26                 1.533333
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52                 2.000000
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee                 1.000000
# 0x76cfcac55192b381cd7b973acd12a58315072032                 1.000000
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c                 1.000000
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41                 2.142857
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a                 1.500000
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2                 1.000000
# 0x2717ae2060084918a338b3a0b3a216cedd810aca                 1.000000
# 0x8073639b11994c549eda58fc3cd7132a72aadf10                 1.000000
# 0x921a05b893021fbdf231e75c02847c70e256917d                 1.000000
#
#                                             prediction
# eoa
# 0x96178dacb4c441efd369a09b5bbb0dace326c7c5         NaN
# 0xf48ce8563f180792352c2e833e2c0746a693a2d5         NaN
# 0x14acdf57dd0f21acfca9e9b0ca2b9b9d3aba285b         NaN
# 0x9e394444243f8fb893cf364ffe4df4ba02ed3a3b         NaN
# 0x958fa668369d42afccd1c255195bb1ef2fe05ef4         NaN
# 0xb9fabfaf84a94ac57b2a429d76d277fff83dd3c8         NaN
# 0x93481c2b2daf2dc77c44504406e28f33c1ffa681         NaN
# 0x712b4018ce224dca5ca9100f63c14893f977167d         NaN
# 0x6182c4b83d2d0de73bf124aaa45a6ef52ba7cb4b         NaN
# 0x43d21aa7d4e8027e7a462e41838fc8d258f91f26         NaN
# 0x25eb8e48af083b7db8e590cfc56eea2ad1306e52         NaN
# 0x17b211277a2ab30e83f1acf9f5f5f33aa3ba30ee         NaN
# 0x76cfcac55192b381cd7b973acd12a58315072032         NaN
# 0x829a6de24ff4c608bf55da742b39954fc9226c7c         NaN
# 0x8f20ca997300ff01df346d5db562759ec2c4cc41         NaN
# 0x425d84e63e623d0ad74d324710e5d0c53656ca7a         NaN
# 0x5b5d6d40da8eb176e8329e328463aac06a5309a2         NaN
# 0x2717ae2060084918a338b3a0b3a216cedd810aca         NaN
# 0x8073639b11994c549eda58fc3cd7132a72aadf10         NaN
# 0x921a05b893021fbdf231e75c02847c70e256917d         NaN

# %% [markdown]
# So the real reason is that many addresses are nan out of the model

# %%
df_features_add.shape
# Out:
# (9333, 14)

# %%
len(a_voter_addresses)
# Out:
# 17023
